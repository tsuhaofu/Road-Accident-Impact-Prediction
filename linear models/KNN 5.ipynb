# %% [markdown]
# # k-NN, n_neighbors = 5

# %%
import numpy as np
import pandas as pd
from math import ceil
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import precision_score,recall_score,f1_score, accuracy_score,confusion_matrix,classification_report

# %%
X_train_df = pd.read_csv("X_train.csv")
y_train_df = pd.read_csv("y_train.csv")
X_test_df = pd.read_csv("X_test.csv")
y_test_df = pd.read_csv("y_test.csv")

X_train = X_train_df.values
X_test = X_test_df.values
y_train = y_train_df["Severity"]
y_test = y_test_df["Severity"]

# %%
# Initialize the Logistic Regression model with adjusted hyperparameters
kn_classifier = KNeighborsClassifier(n_neighbors=5, weights='uniform', algorithm='auto', leaf_size=30, p=2, metric='minkowski')

# Train the model on the scaled training data
kn_classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
def classification_task( model,X_train_scaled, y_train ,X_test_scaled ,y_test, predic,model_name):

    perf_df=pd.DataFrame({'Train_Score':model.score(X_train_scaled,y_train),"Test_Score":model.score(X_test_scaled,y_test),
                       "Precision_Score":precision_score(y_test,predic,average='weighted'),"Recall_Score":recall_score(y_test,predic,average='weighted'),
                       "F1_Score":f1_score(y_test,predic,average='weighted') , "accuracy":accuracy_score(y_test,predic)}, index=[model_name])
    return perf_df

# %%
y_pred = kn_classifier.predict(X_test)

Eval_kn_classifier =classification_task(kn_classifier, X_train, y_train ,X_test, y_test, y_pred,'KNN')
Eval_kn_classifier
# Out:
#      Train_Score  Test_Score  Precision_Score  Recall_Score  F1_Score  \
# KNN     0.865175    0.814575         0.788463      0.814575  0.791205
#
#      accuracy
# KNN  0.814575

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

class_report = classification_report(y_test, y_pred, zero_division=0)
print("Classification Report:")
print(class_report)
# Out:
# Accuracy: 0.81
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.37      0.11      0.17      1081
#            1       0.84      0.94      0.89     79845
#            2       0.62      0.39      0.48     19392
#            3       0.34      0.02      0.03      1443
#
#     accuracy                           0.81    101761
#    macro avg       0.54      0.36      0.39    101761
# weighted avg       0.79      0.81      0.79    101761

# %%
import numpy as np
import pandas as pd
from math import ceil
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import precision_score,recall_score,f1_score, accuracy_score,confusion_matrix,classification_report

# %%
X_train_df = pd.read_csv("X_train.csv")
y_train_df = pd.read_csv("y_train.csv")
X_test_df = pd.read_csv("X_test.csv")
y_test_df = pd.read_csv("y_test.csv")

X_train = X_train_df.values
X_test = X_test_df.values
y_train = y_train_df["Severity"]
y_test = y_test_df["Severity"]

# %%
# Initialize the Logistic Regression model with adjusted hyperparameters
kn_classifier = KNeighborsClassifier(n_neighbors=5, weights='uniform', algorithm='auto', leaf_size=30, p=2, metric='minkowski')

# Train the model on the scaled training data
kn_classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
def classification_task( model,X_train_scaled, y_train ,X_test_scaled ,y_test, predic,model_name):

    perf_df=pd.DataFrame({'Train_Score':model.score(X_train_scaled,y_train),"Test_Score":model.score(X_test_scaled,y_test),
                       "Precision_Score":precision_score(y_test,predic,average='weighted'),"Recall_Score":recall_score(y_test,predic,average='weighted'),
                       "F1_Score":f1_score(y_test,predic,average='weighted') , "accuracy":accuracy_score(y_test,predic)}, index=[model_name])
    return perf_df

# %%
y_pred = kn_classifier.predict(X_test)

Eval_kn_classifier =classification_task(kn_classifier, X_train, y_train ,X_test, y_test, y_pred,'KNN')
Eval_kn_classifier
# Out:
#      Train_Score  Test_Score  Precision_Score  Recall_Score  F1_Score  \
# KNN     0.865175    0.814575         0.788463      0.814575  0.791205
#
#      accuracy
# KNN  0.814575

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

class_report = classification_report(y_test, y_pred, zero_division=0)
print("Classification Report:")
print(class_report)
# Out:
# Accuracy: 0.81
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.37      0.11      0.17      1081
#            1       0.84      0.94      0.89     79845
#            2       0.62      0.39      0.48     19392
#            3       0.34      0.02      0.03      1443
#
#     accuracy                           0.81    101761
#    macro avg       0.54      0.36      0.39    101761
# weighted avg       0.79      0.81      0.79    101761

# %%
import numpy as np
import pandas as pd
from math import ceil
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import precision_score,recall_score,f1_score, accuracy_score,confusion_matrix,classification_report

# %%
X_train_df = pd.read_csv("X_train.csv")
y_train_df = pd.read_csv("y_train.csv")
X_test_df = pd.read_csv("X_test.csv")
y_test_df = pd.read_csv("y_test.csv")

X_train = X_train_df.values
X_test = X_test_df.values
y_train = y_train_df["Severity"]
y_test = y_test_df["Severity"]

# %%
for k in range(1, 21):
  # Initialize the Logistic Regression model with adjusted hyperparameters
  kn_classifier = KNeighborsClassifier(n_neighbors=k, weights='uniform', algorithm='auto', leaf_size=30, p=2, metric='minkowski')

  # Train the model on the scaled training data
  kn_classifier.fit(X_train, y_train)

  def classification_task( model,X_train_scaled, y_train ,X_test_scaled ,y_test, predic,model_name):

    perf_df=pd.DataFrame({'Train_Score':model.score(X_train_scaled,y_train),"Test_Score":model.score(X_test_scaled,y_test),
                       "Precision_Score":precision_score(y_test,predic,average='weighted'),"Recall_Score":recall_score(y_test,predic,average='weighted'),
                       "F1_Score":f1_score(y_test,predic,average='weighted') , "accuracy":accuracy_score(y_test,predic)}, index=[model_name])
    return perf_df

  y_pred = kn_classifier.predict(X_test)

  Eval_kn_classifier =classification_task(kn_classifier, X_train, y_train ,X_test, y_test, y_pred,'KNN')
  Eval_kn_classifier

  class_report = classification_report(y_test, y_pred, zero_division=0)
  print(f"Classification Report for k={k}:")
  print(class_report)
# Out:
# Classification Report for k=1:
#               precision    recall  f1-score   support
#
#            0       0.28      0.26      0.27      1081
#            1       0.85      0.87      0.86     79845
#            2       0.49      0.46      0.47     19392
#            3       0.14      0.12      0.13      1443
#
#     accuracy                           0.77    101761
#    macro avg       0.44      0.43      0.43    101761
# weighted avg       0.77      0.77      0.77    101761
#
# Classification Report for k=2:
#               precision    recall  f1-score   support
#
#            0       0.23      0.38      0.29      1081
#            1       0.82      0.95      0.88     79845
#            2       0.63      0.25      0.36     19392
#            3       0.23      0.02      0.03      1443
#
#     accuracy                           0.80    101761
#    macro avg       0.48      0.40      0.39    101761
# weighted avg       0.77      0.80      0.76    101761
#
# Classification Report for k=3:
#               precision    recall  f1-score   support
#
#            0       0.24      0.19      0.21      1081
#            1       0.85      0.92      0.88     79845
#            2       0.58      0.42      0.48     19392
#            3       0.21      0.03      0.06      1443
#
#     accuracy                           0.80    101761
#    macro avg       0.47      0.39      0.41    101761
# weighted avg       0.78      0.80      0.79    101761
#
# Classification Report for k=4:
#               precision    recall  f1-score   support
#
#            0       0.37      0.18      0.24      1081
#            1       0.83      0.96      0.89     79845
#            2       0.65      0.29      0.40     19392
#            3       0.22      0.01      0.02      1443
#
#     accuracy                           0.81    101761
#    macro avg       0.52      0.36      0.39    101761
# weighted avg       0.78      0.81      0.78    101761
#
# Classification Report for k=5:
#               precision    recall  f1-score   support
#
#            0       0.37      0.11      0.17      1081
#            1       0.84      0.94      0.89     79845
#            2       0.62      0.39      0.48     19392
#            3       0.34      0.02      0.03      1443
#
#     accuracy                           0.81    101761
#    macro avg       0.54      0.36      0.39    101761
# weighted avg       0.79      0.81      0.79    101761
#
# Classification Report for k=6:
#               precision    recall  f1-score   support
#
#            0       0.43      0.12      0.19      1081
#            1       0.83      0.96      0.89     79845
#            2       0.67      0.29      0.41     19392
#            3       0.33      0.01      0.01      1443
#
#     accuracy                           0.81    101761
#    macro avg       0.57      0.35      0.38    101761
# weighted avg       0.79      0.81      0.78    101761
#
# Classification Report for k=7:
#               precision    recall  f1-score   support
#
#            0       0.49      0.08      0.14      1081
#            1       0.84      0.95      0.89     79845
#            2       0.65      0.37      0.47     19392
#            3       0.32      0.01      0.01      1443
#
#     accuracy                           0.82    101761
#    macro avg       0.58      0.35      0.38    101761
# weighted avg       0.79      0.82      0.79    101761
